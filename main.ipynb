# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
from polinomial_approximation import *

# %%
# points of the graph
p = [
    (22, 30),
    (35, 35),
    (26, 2),
    (38, 3),
    (20, math.exp(20-16.693)+0.969),
    (40, 25)
]

# solving for coeficients of the polinomial
coef = mk_coef(p)
for c in coef:
    print(c)

# f - polinomial function
f = mk_polinomial(coef)
x = np.linspace(20, 40, 100)
y = f(x)

# plotting
plt.plot(x, y)
# Out:
# 0.002191080673978181
# -0.3238319830159742
# 18.823105091684475
# -537.4891144546193
# 7536.566824885487
# -41490.60023030672
