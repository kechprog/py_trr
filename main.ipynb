# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
from utils import parse_txt
df = parse_txt()
df
# Out:
#            close      open      high       low  avarage  log_diff
# 1        84010.0   84170.0   83840.0   84010.0   2363.0 -0.002140
# 2        84010.0   84120.0   83850.0   83920.0   1944.0  0.000000
# 3        83920.0   84000.0   83290.0   83370.0   4198.0 -0.001072
# 4        83380.0   83740.0   83320.0   83650.0   2497.0 -0.006455
# 5        83640.0   83810.0   83530.0   83780.0   1511.0  0.003113
# ...          ...       ...       ...       ...      ...       ...
# 282255  116250.0  116900.0  116240.0  116790.0   1343.0  0.002929
# 282256  116780.0  117300.0  116580.0  117250.0   1195.0  0.004549
# 282257  117250.0  117750.0  117250.0  117440.0   1344.0  0.004017
# 282258  117400.0  118300.0  117360.0  118010.0   1217.0  0.001279
# 282259  118010.0  118300.0  117310.0  117500.0    605.0  0.005182
#
# [282259 rows x 6 columns]

# %%
from mpl_toolkits import mplot3d
def f(x, y):
    return 9*x**2 + 9*y**3

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %% [markdown]
# HOW TO EXTREMUMS

# %%
NUM_POINTS = 40
points = df.close.values[-NUM_POINTS:]
if points is None:
    print('No data')
    exit(1)
extremums = []
plt.plot(points, 'bo')
plt.plot(points)

for i in range(1, NUM_POINTS-1):
    if points[i-1] < points[i] > points[i+1] or points[i-1] > points[i] < points[i+1]:
        extremums.append(i)
        plt.plot(i, points[i], 'ro')

# %% [markdown]
# HOW TO ON THE MATH PART

# %%
from sympy import *
import operator, functools

x = symbols('x')
a = symbols('a')
coef = [
    a,
    x-1,
    x+1,
    x-8,
    x-22,
    x-23,
]


f = expand(functools.reduce(operator.mul, coef))
F = integrate(f, x) + symbols('C')
# F.subs(a, 12)
F
# Out:
# C + a*x**6/6 - 53*a*x**5/5 + 865*a*x**4/4 - 3995*a*x**3/3 - 433*a*x**2 + 4048*a*x
